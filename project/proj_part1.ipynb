# %%
import pandas as pd

# %%
old=pd.read_excel('excel_old.xlsx')
new=pd.read_excel('excel_new.xlsx')
new2=pd.read_excel('excel_new.xlsx')

# %%
old
# Out:
#   unique id data point  2020  2021  2022  2023
# 0       abc      var_a    11    56    31    87
# 1       abc      var_b     8    67    99    76
# 2       def      var_a    45    76   121    55
# 3       def      var_b    22    88    43    88
# 4       ghi      var_a    11    34    56    50
# 5       ghi      var_b    33    59    67    49
# 6       jkl      var_a    10    11    12    13
# 7       pqr      var_a    20    30    14    22

# %%
new
# Out:
#   unique id data point  2020  2021  2022  2023
# 0       abc      var_a    11    77    79    87
# 1       abc      var_b     8    88    54    76
# 2       def      var_a    98    87   321    67
# 3       def      var_b    67    65    76    88
# 4       ghi      var_a    23    45    88    50
# 5       ghi      var_b    34    78    95    88
# 6       jkl      var_a    10    11    12    13
# 7       xyz      var_a    10    20    25    30

# %%
new2[2020]=new[2020]-old[2020]
new2[2021]=new[2021]-old[2021]
new2[2022]=new[2022]-old[2022]
new2[2023]=new[2023]-old[2023]

# %%
new2
# Out:
#   unique id data point  2020  2021  2022  2023
# 0       abc      var_a     0    21    48     0
# 1       abc      var_b     0    21   -45     0
# 2       def      var_a    53    11   200    12
# 3       def      var_b    45   -23    33     0
# 4       ghi      var_a    12    11    32     0
# 5       ghi      var_b     1    19    28    39
# 6       jkl      var_a     0     0     0     0
# 7       xyz      var_a   -10   -10    11     8

# %%
def color_negative_red(value):
    color = 'red' if (value!=0 and type(value)!=str) else 'black'
    return 'color: %s' %color
 
    
df_display=new2.style.applymap(color_negative_red)

# %%
df_display
# Out:
# <style  type="text/css" >
#     #T_f633a1c6_381e_11ea_84a6_408d5c241492row0_col0 {
#             color:  black;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row0_col1 {
#             color:  black;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row0_col2 {
#             color:  black;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row0_col3 {
#             color:  red;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row0_col4 {
#             color:  red;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row0_col5 {
#             color:  black;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row1_col0 {
#             color:  black;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row1_col1 {
#             color:  black;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row1_col2 {
#             color:  black;
#         }    #T_f633a1c6_381e_11ea_84a6_408d5c241492row1_col3 {
#             color:  red;
# ...
